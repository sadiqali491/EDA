# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiqali491/EDA/blob/main/Copy_of_My_Final_AirBnb_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Airbnb Booking Analysis (Exploratory data analysis)

# %% [markdown]
# ##### **Project Type**    - EDA/Regression
# ##### **Contribution**    - Individual
# ##### **Done by -** Sadiq Ali

# %% [markdown]
# # **Project Summary -**
#
# Project Objective:
# This project aims to conduct Exploratory Data Analysis (EDA) on a dataset containing Airbnb booking information to gain insights and understand patterns in customer behavior, booking trends, and other relevant factors impacting the hospitality industry. By performing a comprehensive EDA, the goal is to extract meaningful information to guide decision-making, enhance customer experience, and optimize property management strategies.
#
# Work Flow:
#
#    * Data Collection and Description: The project initiates with the collection of a comprehensive dataset from various sources, including Airbnb reservation systems, customer databases, and online booking platforms. The dataset encompasses a wide array of attributes, such as customer demographics, booking dates, property types, booking channels, length of stay, cancellations, special requests, and historical property performance metrics.
#
#    * Data Cleaning and Preprocessing: The collected data undergoes a thorough preprocessing phase to address missing values, outliers, and inconsistencies. Data cleaning techniques are employed to ensure data integrity and accuracy. Irrelevant or redundant features may be eliminated, and categorical variables are appropriately encoded for analysis.
#
#    * Exploratory Data Analysis (EDA): The EDA process encompasses diverse analytical techniques and visualizations, such as statistical summaries, histograms, box plots, scatter plots, heatmaps, etc. This phase aims to uncover insights into booking patterns, pricing trends, property popularity, customer preferences, and other pertinent factors influencing Airbnb bookings.
#
#    * Customer Segmentation: Based on the analysis, the project endeavors to segment customers into distinct groups based on their booking behaviors, demographics, and preferences. This segmentation facilitates the tailoring of marketing strategies and service offerings to specific customer segments, thereby enhancing overall customer satisfaction and property performance.

# %% [markdown]
# # Business Context
#
# ![Airbnb-logo.png](data:image/png;base64,...)
#
# Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings.

# %% [markdown]
# **GitHub Link** -

# %% [markdown]
# https://github.com/sadiqali491/EDA/blob/main/Copy_of_My_Final_AirBnb_EDA.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Problem Statement:
# 1. How are the listings distributed across different neighborhoods (neighbourhood_group and neighbourhood)?
# 2. Which areas have the highest concentration of listings?
# 3. Are there any geographical patterns related to listing prices or room types?
# 4. What is the distribution of listing prices?
# 5. Are there any outliers or extreme values in the price column?
# 6. How do prices vary across different room types and neighborhoods?
# 7. Who are the top hosts (based on host_id or host_name)?
# 8. Investigate correlations between variables (e.g., price and minimum_nights).
# 9. Explore dependencies between room types and other features.
# 10. Identify Missing Data and Impute if Necessary:
# Check for missing values in columns like last_review and reviews_per_month.
# 11. Create visualizations (scatter plots, histograms, heatmaps) to understand relationships and distributions.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1. Gain a competitive edge by making data-driven decisions to enhance overall business performance.
# 2. Utiilize data analysis techniques on Airbnb listings data to derive actionable insights.
#
# 3. Support strategic decision-making for hosts and the Airbnb platform.
#
# 4. Uncover patterns, correlations, and trends within the dataset.
#
# 5. Enable hosts to optimize pricing strategies, enhance listing quality, and improve customer satisfaction.
#
# 6. Drive business growth by empowering hosts to attract more guests and maximize revenue.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from matplotlib import colormaps
from seaborn.widgets import color_palette


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

filepath = '/content/drive/MyDrive/AirBnb EDA/Airbnb NYC 2019.csv'
airbnb_df = pd.read_csv(filepath)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# count of rows and columns in the dataset
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# Airbnb listings dataset with around 49,000 observations and 16 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb_df.duplicated().sum()
# airbnb_df.drop_duplicates(inplace = True) - If any duplicated values are available, to drop
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Dropping the unecessary columns

airbnb_df.drop(['id', 'name', 'host_name', 'last_review'], axis = 1, inplace = True)

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_id                         48895 non-null  int64
#  1   neighbourhood_group             48895 non-null  object
#  2   neighbourhood                   48895 non-null  object
#  3   latitude                        48895 non-null  float64
#  4   longitude                       48895 non-null  float64
#  5   room_type                       48895 non-null  object
#  6   price                           48895 non-null  int64
#  7   minimum_nights                  48895 non-null  int64
#  8   number_of_reviews               48895 non-null  int64
#  9   reviews_per_month               38843 non-null  float64
#  10  calculated_host_listings_count  48895 non-null  int64
#  11  availability_365                48895 non-null  int64
# ...

# %%
airbnb_df.isnull().sum()
# Out:
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airbnb_df.fillna({'reviews_per_month': 0}, inplace = True)

# %%
airbnb_df.reviews_per_month.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1. The data set contains 48895 rows and 16 columns.
# 2. The data set contains null values in the columns are - name(16), host_name(21), last_review(10052), reviews_per_month(10052).

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# ## **Varriables Description**
#
#
#
#    1. **id** - Unique ID
#    2. **name** - Name of the listing
#    3. **host_id** - Unique host_id
#    4. **host_name** - Name of the host
#    5. **neighbourhood_group** - Location
#    6. **neighbourhood** - Area
#    7. **latitude** - Latitude range
#    8. **longitude** - Longitude range
#    9. **room_type** - Type of listing
#    10. **price** - Price of listing
#    11. **minimum_nights** - Minimum nights to be paid for
#    12. n**umber_of reviews** - Number of reviews
#    13. **last_review** - Content of the last review
#    14. **reviews_per_month** - Number of checks per month
#    15. **calculated_host_listing_count** - Total count
#    16. **availability_365** - availability around the year

# %%
# Dataset Columns
airbnb_df.columns
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.889500e+04  48895.000000  48895.000000  48895.000000    48895.000000
# mean   6.762001e+07     40.728949    -73.952170    152.720687        7.029962
# std    7.861097e+07      0.054530      0.046157    240.154170       20.510550
# min    2.438000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    7.822033e+06     40.690100    -73.983070     69.000000        1.000000
# 50%    3.079382e+07     40.723070    -73.955680    106.000000        3.000000
# 75%    1.074344e+08     40.763115    -73.936275    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       48895.000000                    48895.000000
# mean           23.274466           1.090910                        7.143982
# ...

# %% [markdown]
# The .describe() method, describe about the statistical information about the dataset like count, mean, std, min(value), max(value), 25%, 50%, 75% of the dataset.
# the minimun price is zero which is not acceptable in the case of min nights, and also the max nights - 1250 days.

# %%
# Acccesing all the prices greater than 0

airbnb_df=airbnb_df.loc[airbnb_df['price']>0]
airbnb_df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.888400e+04  48884.000000  48884.000000  48884.000000    48884.000000
# mean   6.762203e+07     40.728953    -73.952176    152.755053        7.029887
# std    7.861666e+07      0.054532      0.046159    240.170260       20.512224
# min    2.438000e+03     40.499790    -74.244420     10.000000        1.000000
# 25%    7.817310e+06     40.690100    -73.983080     69.000000        1.000000
# 50%    3.079257e+07     40.723080    -73.955685    106.000000        3.000000
# 75%    1.074344e+08     40.763120    -73.936290    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48884.000000       48884.000000                    48884.000000
# mean           23.271991           1.090800                        7.144628
# ...

# %% [markdown]
# Defining a function named price_correction for replacing the minimum price

# %%
def price_correction(x):
    if x == 0:
      return 100
    else:
      return x

# %%
airbnb_df['price'].apply(price_correction)
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48884, dtype: int64

# %%
airbnb_df['price'].apply(price_correction)
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48884, dtype: int64

# %%
airbnb_df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.888400e+04  48884.000000  48884.000000  48884.000000    48884.000000
# mean   6.762203e+07     40.728953    -73.952176    152.755053        7.029887
# std    7.861666e+07      0.054532      0.046159    240.170260       20.512224
# min    2.438000e+03     40.499790    -74.244420     10.000000        1.000000
# 25%    7.817310e+06     40.690100    -73.983080     69.000000        1.000000
# 50%    3.079257e+07     40.723080    -73.955685    106.000000        3.000000
# 75%    1.074344e+08     40.763120    -73.936290    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48884.000000       48884.000000                    48884.000000
# mean           23.271991           1.090800                        7.144628
# ...

# %% [markdown]
# **Co-relation Matrix**

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
airbnb_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# Checking the duplicate values in the dataset

# %%
# Dataset Duplicate Value Count
airbnb_df.duplicated().sum()
# airbnb_df.drop_duplicates(inplace = True) - If any duplicated values are available, to drop
# Out:
# 0

# %% [markdown]
# Checking Null Values -

# %%
airbnb_df.isnull().sum()
# Out:
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# name = 16, host_name = 21, last_review = 10052, reviews_per_month = 10052

# %% [markdown]
# # Dropping the unecessary columns from the data set

# %%
# Check the column names in your DataFrame
print(airbnb_df.columns)
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# airbnb_df.drop(['id', 'name', 'host_name', 'last_review'], axis = 1, inplace = True)

# %% [markdown]
# # Filling the null values

# %%
airbnb_df.fillna({'reviews_per_month': 0},inplace = True)

# %% [markdown]
# # Displaying the cleaned data set after removing null values and unecessary columns

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48884 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_id                         48884 non-null  int64
#  1   neighbourhood_group             48884 non-null  object
#  2   neighbourhood                   48884 non-null  object
#  3   latitude                        48884 non-null  float64
#  4   longitude                       48884 non-null  float64
#  5   room_type                       48884 non-null  object
#  6   price                           48884 non-null  int64
#  7   minimum_nights                  48884 non-null  int64
#  8   number_of_reviews               48884 non-null  int64
#  9   reviews_per_month               48884 non-null  float64
#  10  calculated_host_listings_count  48884 non-null  int64
#  11  availability_365                48884 non-null  int64
# ...

# %% [markdown]
# # Checking, is there any null values after cleaning the data set

# %%
airbnb_df.isnull().sum()
# Out:
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# # Checking the price colum which contains value as 0

# %%
airbnb_df[airbnb_df['price'] == 0]
# Out:
# Empty DataFrame
# Columns: [host_id, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# # Correcting the price column

# %%
def price_correction(x):
    if x == 0:
      return 100
    else:
      return x

# %% [markdown]
# # Applying the created function for correction of min price

# %%
airbnb_df['price']=airbnb_df['price'].apply(price_correction)

# %%
airbnb_df[airbnb_df['price'] == 0]
# Out:
# Empty DataFrame
# Columns: [host_id, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# # Displaying the corrected price after appling the function

# %%
airbnb_df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.888400e+04  48884.000000  48884.000000  48884.000000    48884.000000
# mean   6.762203e+07     40.728953    -73.952176    152.755053        7.029887
# std    7.861666e+07      0.054532      0.046159    240.170260       20.512224
# min    2.438000e+03     40.499790    -74.244420     10.000000        1.000000
# 25%    7.817310e+06     40.690100    -73.983080     69.000000        1.000000
# 50%    3.079257e+07     40.723080    -73.955685    106.000000        3.000000
# 75%    1.074344e+08     40.763120    -73.936290    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48884.000000       48884.000000                    48884.000000
# mean           23.271991           1.090800                        7.144628
# ...

# %% [markdown]
# # Defining the function to correct the inappropriate minimum nights

# %%
def minimum_nights_correction(x):
   if x > 356:
     return 365
   else:
     return x

# %%
airbnb_df['minimum_nights'] = airbnb_df['minimum_nights'].apply(minimum_nights_correction)

# %% [markdown]
# # Filtering the minimum nights columns

# %%
airbnb_df[airbnb_df['minimum_nights']== 365]
# Out:
#          host_id neighbourhood_group       neighbourhood  latitude  longitude  \
# 700      1359611           Manhattan             Chelsea  40.74618  -74.00392
# 754      1387370           Manhattan             Midtown  40.75282  -73.97315
# 1305     2798644            Brooklyn            Bushwick  40.70202  -73.92402
# 1449     3260084           Manhattan             Chelsea  40.75164  -73.99425
# 2150     4000059            Brooklyn          Park Slope  40.67359  -73.97434
# 2214     5709288           Manhattan             Midtown  40.75879  -73.96380
# 2831     8457613           Manhattan            Gramercy  40.73494  -73.98751
# 2854     6676776           Manhattan   Battery Park City  40.71239  -74.01620
# 3398     4191006           Manhattan        West Village  40.73858  -74.00875
# 3945     9991763           Manhattan  Financial District  40.70781  -74.00701
# 4372      160337           Manhattan  Washington Heights  40.83549  -73.94765
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Data Manipulations:**
# 1. **Duplicate Values:**
#    - Checked and removed any duplicate entries in the dataset.
#
# 2. **Handling Missing Values:**
#    - Investigated and filled missing values in the 'reviews_per_month' column with zeros.
#    - Dropped unnecessary columns ('id', 'name', 'host_name', 'last_review').
#
# 3. **Handling Zero Price Values:**
#    - Identified and addressed rows with zero prices by applying a correction function.
#
# 4. **Handling Outliers in 'minimum_nights':**
#    - Applied a correction function to address outliers in the 'minimum_nights' column.
#
# **Data Insights:**
# 1. **Price Distribution:**
#    - Explored the distribution of prices after the correction to identify any remaining extreme values.
#
# 2. **Minimum Nights Analysis:**
#    - Analyzed the distribution of 'minimum_nights' after correction to assess the effectiveness of outlier handling.
#
# 3. **Impact of Missing Values:**
#    - Assessed the impact of filling missing values in 'reviews_per_month' on the overall dataset.
#
# 4. **Changes in Descriptive Statistics:**
#    - Examined changes in summary statistics (mean, median, etc.) after manipulations, especially in relation to 'price' and 'minimum_nights'.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# # Corelation Matrix

# %%
from matplotlib import colormaps

# %%
plt.figure(figsize = (15, 8))
title = 'Corelation Matrix of numerical varriables'
sns.heatmap(airbnb_df.corr(method = "kendall"), cmap = 'viridis', square = True, annot = True)
plt.title(title)
plt.show()
# Out:
# <ipython-input-40-f9a1b36f9159>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(airbnb_df.corr(method = "kendall"), cmap = 'viridis', square = True, annot = True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Choice of Chart: A heatmap is chosen to visualize the correlation matrix of numerical variables.
#
# * Reasoning: Heatmaps are effective for displaying relationships between variables, making it easier to identify patterns and correlations in a matrix of numerical values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Positive correlations**: There are positive correlations between variables like ‘host_id’ and ‘id’, ‘latitude’ and ‘price’, indicating that as one variable increases, the other tends to increase as well. This could imply that hosts with higher IDs (i.e., newer hosts) tend to have higher listing IDs (i.e., newer listings) and charge higher prices. It could also imply that properties located at higher latitudes (i.e., closer to the city center) tend to have higher prices.
#
# **Negative correlations**: There are negative correlations between variables like ‘availability_365’ and ‘reviews_per_month’, indicating that as the availability increases, the reviews per month tend to decrease. This could imply that properties with higher availability (i.e., less booked) tend to have lower reviews per month (i.e., less popular or less rated).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact**:
# The positive correlations between host_id, id, and price could suggest that there is a healthy growth of new hosts and listings in the market, and that they are able to charge competitive prices. This could benefit both the hosts and Airbnb as a platform, as it could increase the revenue and the customer base.
#
# **Negative business impact**:
# The negative correlation between availability_365 and reviews_per_month could suggest that there is an oversupply of properties in the market, and that they are not attracting enough customers or ratings. This could harm both the hosts and Airbnb as a platform, as it could decrease the occupancy rate and the customer satisfaction.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# Is Manhatthan neighnourhood more preffered over other neighbourhoods?

# %% [markdown]
# # Analysing the neighbourhood group

# %% [markdown]
# # Finding out the unique data present in the neighbourhood group column

# %%
airbnb_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# # Checking the total value counts for each neighbourhood_group

# %%
neighbourhood_group_counts = airbnb_df['neighbourhood_group'].value_counts()
neighbourhood_group_counts
# Out:
# Manhattan        21660
# Brooklyn         20095
# Queens            5666
# Bronx             1090
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# # Creating a datframe for neighbourhood_groups and value counts

# %%
neighbourhood_group_counts = pd.DataFrame(data = neighbourhood_group_counts)
neighbourhood_group_counts.reset_index(inplace = True)
neighbourhood_group_counts.rename(columns = {'index': 'Neighbourhood_Group','neighbourhood_group':'Counts'}, inplace = True)

# %%
neighbourhood_group_counts
# Out:
#   Neighbourhood_Group  Counts
# 0           Manhattan   21660
# 1            Brooklyn   20095
# 2              Queens    5666
# 3               Bronx    1090
# 4       Staten Island     373

# %% [markdown]
# # Plotting the bar plot using dataframe

# %%
from seaborn.widgets import color_palette

fig_1 = sns.barplot(x=neighbourhood_group_counts['Neighbourhood_Group'], y = neighbourhood_group_counts['Counts'], palette='viridis')

fig_1.set_title('Listings in each Neighbourhood')
fig_1.set_xlabel('Neighbourhood_Group')
fig_1.set_ylabel('Counts')
plt.show()
# Out:
# <ipython-input-45-822f61f29888>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   fig_1 = sns.barplot(x=neighbourhood_group_counts['Neighbourhood_Group'], y = neighbourhood_group_counts['Counts'], palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Choice of Chart: A bar plot is chosen to visualize the number of listings in each neighborhood group.
#
# * Reasoning: Bar plots are effective for displaying and comparing the counts of different categories, making it easy to interpret the distribution of listings across neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#
#
# * The 'Set1' color palette enhances visualization by providing distinct colors for each neighborhood group.
#
# * Manhattan and Brooklyn have a significantly higher number of listings compared to Queens, Bronx, and Staten Island.
#
# * The chart provides a clear representation of the distribution of listings, enabling a quick understanding of popularity across neighborhood groups.
#
#
#
# * Manhattan and Brooklyn dominate the market: These two neighbourhood groups have the highest number of listings, indicating a strong demand and supply for Airbnb properties in these areas.
#
# * Queens, Bronx, and Staten Island lag behind: These three neighbourhood groups have significantly fewer listings, suggesting a lower market presence and potential for Airbnb properties in these areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# * Understanding the popularity and distribution of listings in each neighborhood group can help in strategic decision-making.
# * Tailoring marketing strategies, allocating resources effectively, and responding to high demand areas can positively impact business growth.
#
#
#
#
# Potential Negative Growth Considerations:
#
# * Market Saturation: If Manhattan and Brooklyn have significantly more listings, it might indicate a high level of competition and market saturation in these areas. This could make it challenging for new listings to gain visibility and attract bookings.
#
# * Uneven Distribution: A concentration of listings in specific neighborhood groups might result in uneven utilization of resources. Neglecting less popular areas may lead to missed opportunities or dissatisfaction among hosts in those regions.
#
# * Limited Diversity: If the majority of listings are concentrated in a few neighborhood groups, it may limit the overall diversity of offerings on the platform. This could potentially lead to a less varied experience for users.
#
#
#
# Mitigation Strategies:
#
#
# * Market Diversification: Encouraging and supporting hosts in less popular neighborhoods to join the platform can help diversify the listings and provide users with a broader range of options.
#
# * Strategic Marketing: Implementing targeted marketing strategies to boost visibility in less saturated markets can help balance demand and supply.
#
# * Resource Allocation: Ensuring that resources, such as customer support and promotional efforts, are distributed strategically across all neighborhood groups can prevent neglect of less popular areas.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# **Distribution of listings across neighbourhood**

# %%
fig_2 = sns.countplot(x = 'neighbourhood_group', hue = 'room_type', data = airbnb_df,palette='viridis')
title = 'Room Type Loaction Per Neighbourhood Group'
plt.title(title)
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# * Choice of Chart: A countplot is selected to visualize the distribution of room types within each neighborhood group.
# *
# Reasoning: Countplots are effective for displaying the frequency of categorical variables, and the use of hue allows for comparison across two categorical variables (room type and neighborhood group) simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights:
#
#
# * The countplot illustrates the distribution of different room types within each neighborhood group.
#
# * It facilitates a comparison of how room types vary across neighborhood groups.
#
# * The use of color (hue) distinguishes room types within each neighborhood group, providing a clear visual representation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
#
#
# * Understanding the distribution of room types across neighborhood groups can guide marketing strategies and help tailor promotions based on popular room types in specific areas.
#
# * It provides valuable insights into the preferences of guests in different locations, allowing hosts and Airbnb to optimize their offerings.
#
#
# Potential Negative Growth Considerations:
#
#
# * Room Type Disparities: If the countplot reveals a significant imbalance in the distribution of room types across neighborhood groups, it may lead to negative growth.
#
# * Reasoning: A disproportionate concentration of a particular room type in certain neighborhoods might indicate a mismatch between supply and demand. For example, an excess of shared rooms in an area with a preference for entire homes might lead to lower occupancy rates and potentially negative growth for hosts offering less preferred room types.
#
# Mitigation Strategies:
#
#
#
# * Dynamic Pricing: Implementing dynamic pricing strategies to incentivize certain room types in specific neighborhoods based on demand can help balance the distribution.
#
# * Dynamic Pricing: Implementing dynamic pricing strategies to incentivize certain room types in specific neighborhoods based on demand can help balance the distribution.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# **Distribution of Room types**

# %%
# Assuming you have a DataFrame named 'airbnb_df'
# Replace 'airbnb_df' with your actual DataFrame name

title = 'Map of Neighbourhood Group Location'
sns.set(rc={'figure.figsize': (12, 6)})

# Create the scatter plot
scatter_plot = sns.scatterplot(x=airbnb_df['longitude'], y=airbnb_df['latitude'], hue=airbnb_df['neighbourhood_group'], palette='viridis')

# Iterate through unique values of 'neighbourhood_group' for labeling
for group, data in airbnb_df.groupby('neighbourhood_group'):
    group_center = data[['longitude', 'latitude']].mean()
    scatter_plot.text(group_center['longitude'], group_center['latitude'], group, horizontalalignment='center', verticalalignment='center', fontsize=8, backgroundcolor='white', color='black')

# Add legend to the top-right corner
plt.legend(title='Neighbourhood Group', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title(title)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A scatter plot is selected to visualize the geographical distribution of Airbnb listings across different neighborhood groups.
#
# Reasoning: Scatter plots are ideal for displaying the relationship between two continuous variables (latitude and longitude in this case) and can effectively represent spatial patterns. The use of color (hue) further allows differentiation based on the categorical variable 'neighbourhood_group,' providing a comprehensive view of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Geographical distribution**: The chart shows the spatial distribution of Airbnb listings across different neighborhood groups in New York City. Each group is represented by a different color, and the density of dots indicates the concentration of listings in those areas.
# - **Brooklyn's popularity**: Brooklyn has the highest number of Airbnb listings, as indicated by the dense cluster of purple dots. This suggests that Brooklyn is a popular destination for travelers and hosts alike, offering a variety of accommodation options and attractions.
# - **Manhattan's scarcity**: Manhattan has a lower number of Airbnb listings compared to Brooklyn, despite being the most central and iconic area of New York City. This could imply that Manhattan has a higher demand and lower supply of Airbnb properties, resulting in higher prices and lower availability.
# - **Staten Island's isolation**: Staten Island has the lowest number of Airbnb listings among all neighborhood groups, as shown by the sparse red dots. This could indicate that Staten Island is less accessible and attractive for travelers and hosts, being separated from the rest of the city by water and having fewer transportation options.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. **Potential Business Impact**:
#
# Visualizing the geographical distribution of Airbnb listings across different neighborhood groups aids in understanding the spatial patterns of demand.
#
# It can inform location-specific marketing strategies, helping hosts and Airbnb optimize promotional efforts and target high-demand areas.
#
# 2. **Potential Negative Growth Considerations and Reasoning**:
#
# Spatial Imbalances: If the scatter plot reveals uneven distribution or clustering of listings in specific geographical areas, it may pose challenges.
#
# Reasoning: Concentrated listings in certain regions might result in oversaturation and increased competition, potentially leading to negative growth as hosts struggle to attract bookings in less crowded areas.
#
# 3. **Mitigation Strategies**:
#
# Diversification Campaigns: Encouraging hosts to list properties in less saturated areas can promote a more even distribution of listings.
#
# Localized Marketing: Implementing location-specific marketing campaigns can help boost visibility in areas with lower listing concentrations.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# Price of each neighbourhood group

# %%
title = 'Price of each neighbourhood group'
plt.style.use('ggplot')
price_500 = airbnb_df[airbnb_df.price < 700]
plt.figure(figsize = (10, 6))
plt.title(title)
sns.boxplot(x = 'neighbourhood_group', y = 'price', data = price_500,palette='viridis')
plt.show()
# Out:
# <ipython-input-48-c2b45a49a604>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'neighbourhood_group', y = 'price', data = price_500,palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# choice of Chart: A boxplot was chosen to visualize the distribution of prices for each neighborhood group in the dataset.
#
# Reasoning: Boxplots effectively display central tendency, spread, and potential outliers within different groups, providing a clear comparison of pricing distributions across neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Manhattan's premium**: Manhattan has the highest median property price among all neighborhood groups, indicating that it is the most desirable and expensive area to stay in New York City. This could be due to factors such as location, amenities, attractions, and demand.
#
# - **Brooklyn's diversity**: Brooklyn has the second highest median property price, but also the widest range of prices, as shown by the long whiskers on its box plot. This suggests that Brooklyn has a diverse mix of properties, from budget-friendly to luxury, catering to different customer segments and preferences.
#
# - **Bronx's affordability**: The Bronx has the lowest median property price and the smallest interquartile range, meaning that most properties in this neighborhood group are priced similarly and affordably. This could be an opportunity for customers who are looking for cheaper accommodation options in New York City.
#
# - **Queens and Staten Island's similarity**: Queens and Staten Island have similar median property prices and interquartile ranges, indicating that they have comparable levels of price and quality in their properties. They are both lower than Manhattan and Brooklyn, but higher than the Bronx, in terms of price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# The insights derived from the boxplot can positively impact business strategies.
#
# Understanding the distribution of prices across neighborhood groups is crucial for pricing optimization, enabling hosts and Airbnb to tailor pricing models and promotions.
#
# It facilitates the adjustment of pricing strategies to align with the expectations and preferences of guests in specific areas.
#
#
#
# Potential Negative Growth Considerations and Reasoning:
#
# Spatial Imbalances: If the boxplot reveals significant disparities or outliers in pricing across neighborhood groups, it may pose challenges.
#
# Reasoning: Pricing imbalances might impact customer satisfaction and overall business performance. For example, higher prices in specific areas may deter potential bookings and hinder growth.
#
#
# Mitigation Strategies:
#
#
# Dynamic Pricing Models: Implementing dynamic pricing strategies based on neighborhood-specific factors can address pricing imbalances and optimize revenue.
#
# Localized Promotions: Introducing localized promotional campaigns for areas with pricing challenges can help attract bookings and balance demand.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# Mean price V/S Neighbourhood group

# %%
neigh_group_price_group = airbnb_df.groupby(['neighbourhood_group']).agg({'price': 'mean'}).reset_index()
neigh_group_price_group
# Out:
#   neighbourhood_group       price
# 0               Bronx   87.577064
# 1            Brooklyn  124.438915
# 2           Manhattan  196.884903
# 3              Queens   99.517649
# 4       Staten Island  114.812332

# %%
title = 'Mean price v/s Neighbourhood group'
plt.figure(figsize = (15, 5))
ax_1 = sns.barplot(x = 'neighbourhood_group', y = 'price', data = neigh_group_price_group,palette='viridis')
ax_1.set_title(title)
ax_1.set_xlabel('Neighbourhood Group')
ax_1.set_ylabel('Mean Price')
plt.show()
# Out:
# <ipython-input-50-c06126ac7492>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_1 = sns.barplot(x = 'neighbourhood_group', y = 'price', data = neigh_group_price_group,palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A bar plot was selected to visualize the mean prices for each neighborhood group.
#
# Reasoning: Bar plots are effective for comparing the mean values of a variable across different categories. In this case, it provides a clear representation of the average prices in each neighborhood group, facilitating easy comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights:
# The bar plot illustrates the mean prices for each neighborhood group.
#
# It allows for a quick comparison of average prices across different neighborhood groups, providing insights into potential pricing trends and variations.
#
# The visualization highlights the relative affordability or luxury of accommodations in each neighborhood group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# Understanding the mean prices across neighborhood groups is essential for pricing strategies.
#
# It enables hosts and Airbnb to make informed decisions about setting competitive and attractive pricing for accommodations.
#
# This insight can be used to optimize pricing models, cater to diverse customer segments, and enhance overall customer satisfaction.
#
#
# Potential Negative Growth Considerations and Reasoning:
#
# Pricing Disparities: If the bar plot reveals significant disparities in mean prices across neighborhood groups, it may pose challenges.
#
# Reasoning: Large variations in pricing could lead to customer dissatisfaction or the perception of unfair pricing practices, potentially impacting bookings and hindering overall growth.
#
#
# Mitigation Strategies:
#
# Dynamic Pricing Strategies: Implementing dynamic pricing models based on demand, seasonality, and local factors can help balance pricing disparities.
#
# Transparent Communication: Communicating transparently with customers about pricing factors can help manage expectations and mitigate potential negative perceptions.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# Price V/S Room Type

# %%
# Chart - 7 visualization code
title = 'Price v/s Room Type'
plt.figure(figsize = (15, 5))
ax_3 = sns.barplot(x = 'room_type', y = 'price', data = airbnb_df,palette='viridis')
ax_3.set_title(title)
ax_3.set_xlabel('Room Type')
ax_3.set_ylabel('Price')
plt.show()
# Out:
# <ipython-input-51-6aa183c16b8b>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_3 = sns.barplot(x = 'room_type', y = 'price', data = airbnb_df,palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A bar plot was chosen to visualize the relationship between room types and their respective prices.
#
# Reasoning: Bar plots effectively represent the comparison of mean values across different categories. In this context, it provides a clear visual representation of the average prices associated with each room type, allowing for easy comparison and identification of pricing patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights:
#
# The bar plot illustrates the relationship between room types and their corresponding prices.
#
# It allows for a quick comparison of average prices for different room types, providing insights into the relative pricing levels of shared rooms, private rooms, and entire homes/apartments.
#
# The visualization highlights potential trends in pricing based on accommodation types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# Understanding the relationship between room types and prices is crucial for pricing strategies.
#
# It enables hosts and Airbnb to make informed decisions about setting competitive prices for different accommodation types.
#
# This insight can be used to optimize pricing models, cater to diverse customer preferences, and enhance overall customer satisfaction.
#
#
# Potential Negative Growth Considerations and Reasoning:
#
#
# Pricing Mismatches: If the bar plot reveals significant pricing mismatches or discrepancies among room types, it may pose challenges.
#
# Reasoning: Wide variations in pricing for similar room types might lead to customer dissatisfaction or the perception of unfair pricing practices, potentially impacting bookings and hindering overall growth.
#
#
# Mitigation Strategies:
#
#
# Consistent Pricing Guidelines: Implementing consistent pricing guidelines for similar room types can help avoid customer confusion and dissatisfaction.
#
# Dynamic Pricing Models: Utilizing dynamic pricing models based on demand and other factors can ensure that prices are competitive and reflective of market conditions.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# # Analysing Price With Other Factors
#
# 1.  Minimum_nights
# 2.  Number_of_reviews
# 3. Calculated_host_listing_counts
# 4. Reviews_per_month

# %% [markdown]
# # 1. Minimun nights v/s price

# %%
title = 'Minimum_nights v/s price'
sns.relplot(x = 'minimum_nights', y = 'price', data = airbnb_df, hue = 'room_type',palette='viridis') # relational plot - It is useed for comparing relation between 2 varriables eg- Numerical, categorical etc.
plt.title(title)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A relational plot (scatter plot with hue) was selected to visualize the relationship between minimum nights and prices, considering different room types.
#
# Reasoning: Relational plots are suitable for comparing relationships between two variables, and the addition of hue allows differentiation based on the categorical variable 'room_type.' This enables the examination of how minimum nights and prices vary for different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The relational plot illustrates the relationship between minimum nights and prices.
#
# Different room types are distinguished by color, providing insights into how the relationship varies across shared rooms, private rooms, and entire homes/apartments.
#
# The visualization allows for the identification of patterns and potential correlations between minimum nights and prices based on room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# Understanding the relationship between minimum nights and prices for different room types is valuable for pricing and marketing strategies.
#
# It enables hosts and Airbnb to tailor minimum night requirements and pricing based on room types, accommodating the preferences of diverse customer segments.
#
# This insight can contribute to optimizing booking strategies and improving overall customer satisfaction.
#
#
#
# Potential Negative Growth Considerations and Reasoning:
#
#
# Mismatched Pricing and Minimum Nights: If the relational plot reveals inconsistent patterns or significant mismatches in pricing and minimum nights for similar room types, it may pose challenges.
#
#
# Reasoning: Inconsistencies might lead to customer dissatisfaction or the perception of unfair pricing practices, potentially impacting bookings and hindering overall growth.
#
# Mitigation Strategies:
#
#
# Consistent Pricing Guidelines: Implementing consistent pricing guidelines for similar room types can help avoid customer confusion and dissatisfaction.
#
# Customized Minimum Night Requirements: Tailoring minimum night requirements based on room types and customer preferences can enhance the booking experience.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# # 2. Number of reviews v/s Price

# %%
# Chart - 9 visualization code

# %%
title = 'Number_of_reviews v/s price'
sns.relplot(x = 'number_of_reviews', y = 'price', data = airbnb_df, hue = 'room_type',palette='viridis')
plt.title(title)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A relational plot (scatter plot with hue) was selected to visualize the relationship between the number of reviews and prices, considering different room types.
#
#
# Reasoning: Relational plots are effective for comparing relationships between two variables, and the addition of hue allows differentiation based on the categorical variable 'room_type.' This enables the examination of how the number of reviews and prices vary for different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The relational plot illustrates the relationship between the number of reviews and prices.
#
# Different room types are distinguished by color, providing insights into how the relationship varies across shared rooms, private rooms, and entire homes/apartments.
#
# The visualization allows for the identification of patterns and potential correlations between the number of reviews and prices based on room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# Understanding the relationship between the number of reviews and prices for different room types is valuable for pricing and marketing strategies.
#
# It enables hosts and Airbnb to optimize pricing and promotional efforts based on the number of reviews, fostering customer trust and attracting potential guests.
#
# This insight can contribute to enhancing overall customer satisfaction and driving positive business impact.
#
#
#
# Potential Negative Growth Considerations and Reasoning:
#
# Mismatched Pricing and Review Counts: If the relational plot reveals inconsistencies or significant mismatches in pricing and the number of reviews for similar room types, it may pose challenges.
#
# Reasoning: Inconsistencies might lead to customer dissatisfaction or the perception of unfair pricing practices, potentially impacting bookings and hindering overall growth.
#
#
#
# Mitigation Strategies:
#
# Consistent Pricing Guidelines: Implementing consistent pricing guidelines for similar room types can help avoid customer confusion and dissatisfaction.
#
# Strategic Promotion: Developing promotional strategies based on the number of reviews can enhance the attractiveness of listings and encourage bookings.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# # 3. Calculated host listings count v/s price

# %%
# Chart - 10 visualization code

# %%
title = 'Calculated host listings count v/s price'
sns.relplot(x = 'calculated_host_listings_count', y = 'price', data = airbnb_df, hue = 'room_type',palette='viridis')
plt.title(title)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A relational plot (scatter plot with hue) was selected to visualize the relationship between the calculated host listings count and prices, considering different room types.
#
# Reasoning: Relational plots are effective for comparing relationships between two variables, and the addition of hue allows differentiation based on the categorical variable 'room_type.' This enables the examination of how the calculated host listings count and prices vary for different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights:
#
# The relational plot illustrates the relationship between the calculated host listings count and prices.
#
# Different room types are distinguished by color, providing insights into how the relationship varies across shared rooms, private rooms, and entire homes/apartments.
#
# The visualization allows for the identification of patterns and potential correlations between the host listings count and prices based on room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# Understanding the relationship between the calculated host listings count and prices for different room types is valuable for both hosts and Airbnb.
#
# It enables hosts to optimize their listing strategies based on the number of listings, potentially adjusting prices for competitiveness.
#
# For Airbnb, this insight aids in tailoring support and promotional efforts for hosts with varying listing counts, contributing to a positive overall business impact.
#
# 4. Potential Negative Growth Considerations and Reasoning:
#
# Inconsistent Pricing and Host Listings Count: If the relational plot reveals inconsistencies or significant mismatches in pricing and host listings count for similar room types, it may pose challenges.
#
# Reasoning: Inconsistencies might lead to customer dissatisfaction or the perception of unfair pricing practices, potentially impacting bookings and hindering overall growth.
#
# 5. Mitigation Strategies:
#
#
# Consistent Pricing Guidelines: Implementing consistent pricing guidelines for similar room types can help avoid customer confusion and dissatisfaction.
#
#
# Host Education: Providing hosts with guidance on pricing strategies based on their calculated listings count can contribute to a more balanced approach.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# # 4. Reviews per month v/s price

# %%
# Chart - 11 visualization code

# %%
title = 'Reviews per month v/s price'
sns.relplot(x = 'reviews_per_month', y = 'price', data = airbnb_df, hue = 'room_type',palette='viridis')
plt.title(title)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A relational plot (scatter plot with hue) was selected to visualize the relationship between reviews per month and prices, considering different room types.
#
# Reasoning: Relational plots are effective for comparing relationships between two variables, and the addition of hue allows differentiation based on the categorical variable 'room_type.' This enables the examination of how reviews per month and prices vary for different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Price and reviews trade-off**: There is a negative correlation between price and reviews per month, meaning that customers tend to prefer cheaper options and leave more reviews for them. This could imply that customers are more price-sensitive and value-for-money oriented in this market.
#
# **Room type preference**:The majority of the data points are for private rooms and entire homes/apartments, indicating that these are the most popular and available room types in this market. Shared rooms have the least data points, suggesting that they are less preferred by customers and/or less offered by hosts.
#
# **Price distribution:** The price range is wide, from 0 to 8000, but most data points are concentrated at the lower end of the price spectrum, below 1000. This could indicate that there is a high demand and supply for budget-friendly accommodation options in this market, and that the high-priced options are outliers or niche segments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# Understanding the relationship between reviews per month and prices for different room types is valuable for both hosts and Airbnb.
#
# It enables hosts to optimize their pricing and promotional strategies based on the volume and frequency of reviews, potentially adjusting prices for competitiveness.
#
# For Airbnb, this insight aids in tailoring support and promotional efforts for hosts with varying review frequencies, contributing to a positive overall business impact.
#
# 4. Potential Negative Growth Considerations and Reasoning:
#
# Inconsistent Pricing and Review Counts: If the relational plot reveals inconsistencies or significant mismatches in pricing and reviews per month for similar room types, it may pose challenges.
#
# Reasoning: Inconsistencies might lead to customer dissatisfaction or the perception of unfair pricing practices, potentially impacting bookings and hindering overall growth.
#
# 5. Mitigation Strategies:
#
# Consistent Pricing Guidelines: Implementing consistent pricing guidelines for similar room types can help avoid customer confusion and dissatisfaction.
#
# Review-Based Promotions: Introducing promotions or incentives based on review counts can encourage hosts to maintain quality service and encourage positive guest feedback.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# # Top 10 expensive neighbourhood based on the average price

# %%
title = 'Top 10 expensive neighbourhood based on the average price'

top_ex = airbnb_df.groupby(["neighbourhood"])['price'].agg(np.mean).reset_index().sort_values('price')
sns.barplot(x='price', y='neighbourhood', data = top_ex[-10:], label = 'Total', palette = 'viridis')
plt.xlabel('Average Price')
plt.title(title)
plt.show()
# Out:
# <ipython-input-60-caa6d762ef3f>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='price', y='neighbourhood', data = top_ex[-10:], label = 'Total', palette = 'viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A horizontal bar chart was selected to visualize the top 10 expensive neighborhoods based on the average price.
#
# Reasoning: Bar plots effectively display comparisons, and in this case, it allows for a clear representation of the average prices for different neighborhoods. Sorting the neighborhoods based on average price provides a focused view of the top 10 expensive ones.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot illustrates the average prices for the top 10 expensive neighborhoods.
#
# It provides a straightforward comparison of average prices, allowing users to identify which neighborhoods have higher pricing.
#
# The visualization highlights the relative costliness of accommodations in these specific neighborhoods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# Understanding the neighborhoods with higher average prices is essential for pricing and marketing strategies.
#
# It allows hosts and Airbnb to tailor their marketing efforts and pricing models for specific high-end neighborhoods, potentially attracting more discerning guests.
#
# This insight contributes to optimizing pricing strategies and enhancing overall customer satisfaction for those seeking premium accommodations.
#
# 4. Potential Negative Growth Considerations and Reasoning:
#
# Limited Diversity in Pricing: If the bar plot reveals a concentration of high prices in a few neighborhoods, it may pose challenges.
#
# Reasoning: Limited diversity in pricing might result in a smaller target audience, potentially limiting growth opportunities. Additionally, it might lead to increased competition among hosts in these neighborhoods.
#
# 5. Mitigation Strategies:
#
# Diversified Marketing Strategies: Implementing diversified marketing strategies for neighborhoods with varying price ranges can broaden the target audience.
#
#
# Encouraging Listings in Diverse Areas: Encouraging hosts to list properties in a broader range of neighborhoods can contribute to a more balanced distribution of listings.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# # Top 10 inexpensive neighbourhood based on the average price

# %%
# Chart - 13 visualization code

# %%
top_lex = airbnb_df.groupby(["neighbourhood"])['price'].agg(np.mean).reset_index().sort_values('price')
sns.barplot(x='price', y='neighbourhood', data = top_lex[:10], label = 'Total', palette = 'viridis')
plt.xlabel('Average Price')
plt.title(title)
plt.show()
# Out:
# <ipython-input-62-c48170490f4b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='price', y='neighbourhood', data = top_lex[:10], label = 'Total', palette = 'viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choice of Chart: A bar plot was selected to visualize the top 10 least expensive neighborhoods based on the average price.
#
# Reasoning: Bar plots effectively display comparisons, and in this case, it allows for a clear representation of the average prices for different neighborhoods. Sorting the neighborhoods based on average price provides a focused view of the top 10 least expensive ones.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot illustrates the average prices for the top 10 least expensive neighborhoods.
#
# It provides a straightforward comparison of average prices, allowing users to identify which neighborhoods have lower pricing.
#
# The visualization highlights the relative affordability of accommodations in these specific neighborhoods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Potential Business Impact:
#
# Understanding the neighborhoods with lower average prices is valuable for pricing and marketing strategies.
#
# It allows hosts and Airbnb to target cost-conscious travelers and tailor marketing efforts for specific budget-friendly neighborhoods.
#
# This insight contributes to optimizing pricing strategies and expanding the customer base by appealing to those seeking more affordable accommodations.
#
# 4. Potential Negative Growth Considerations and Reasoning:
#
# Potential Perceptions of Lower Quality: If the bar plot reveals a concentration of lower prices in a few neighborhoods, it may pose challenges.
#
# Reasoning: Lower prices might lead to perceptions of lower quality, potentially impacting customer trust and satisfaction. It may also result in increased competition among hosts in these neighborhoods.
#
# 5. Mitigation Strategies:
#
#
# Quality Assurance: Implementing quality assurance measures and promoting positive guest experiences can help counter potential perceptions of lower quality.
#
#
# Strategic Marketing for Value: Emphasizing the value and unique offerings in lower-priced neighborhoods can attract budget-conscious travelers.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

from matplotlib import colormaps

plt.figure(figsize = (15, 8))
title = 'Corelation Matrix of numerical varriables'
sns.heatmap(airbnb_df.corr(method = "kendall"), cmap = 'viridis', square = True, annot = True)
plt.title(title)
plt.show()
# Out:
# <ipython-input-63-4a8c5329124d>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(airbnb_df.corr(method = "kendall"), cmap = 'viridis', square = True, annot = True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Choice of Chart: A heatmap is chosen to visualize the correlation matrix of numerical variables.
#
# Reasoning: Heatmaps are effective for displaying relationships between variables, making it easier to identify patterns and correlations in a matrix of numerical values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# **Positive correlations**:
# There are positive correlations between variables like ‘host_id’ and ‘id’, ‘latitude’ and ‘price’, indicating that as one variable increases, the other tends to increase as well. This could imply that hosts with higher IDs (i.e., newer hosts) tend to have higher listing IDs (i.e., newer listings) and charge higher prices. It could also imply that properties located at higher latitudes (i.e., closer to the city center) tend to have higher prices.
#
# **Negative correlations**:
# There are negative correlations between variables like ‘availability_365’ and ‘reviews_per_month’, indicating that as the availability increases, the reviews per month tend to decrease. This could imply that properties with higher availability (i.e., less booked) tend to have lower reviews per month (i.e., less popular or less rated).

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive business impact: The positive correlations between host_id, id, and price could suggest that there is a healthy growth of new hosts and listings in the market, and that they are able to charge competitive prices. This could benefit both the hosts and Airbnb as a platform, as it could increase the revenue and the customer base.
#
# Negative business impact: The negative correlation between availability_365 and reviews_per_month could suggest that there is an oversupply of properties in the market, and that they are not attracting enough customers or ratings. This could harm both the hosts and Airbnb as a platform, as it could decrease the occupancy rate and the customer satisfaction.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
sns.pairplot(airbnb_df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because Pair plot gives the detailed Explanation of the given data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A pair plot consists of multiple scatterplots arranged in a grid, with each scatterplot showing the relationship between two variables
#
# It can be used to visualize relationships between multiple variables and to identify patterns in the data.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve business objectives with an Airbnb dataset, a comprehensive strategy is essential. Firstly, optimizing pricing strategies using historical booking data and market trends enables hosts to maximize revenue while remaining competitive. Enhancing guest experience is paramount, achieved through proactive measures like analyzing feedback to improve amenities and communication, leading to higher satisfaction and repeat bookings.
#
# Expanding market reach involves targeted marketing and partnerships to tap into new segments or underutilized markets, boosting occupancy rates. Streamlining operations through technology integration ensures efficiency, reducing costs and freeing up time for guest-focused activities. Lastly, compliance with local regulations is critical for maintaining trust and avoiding legal issues.
#
# By implementing these strategies, hosts can unlock untapped revenue potential, foster guest loyalty, and drive sustainable growth in the Airbnb marketplace.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Through our analysis of the Airbnb dataset, we've extracted valuable insights crucial for hosts and stakeholders to optimize their operations. By examining seasonal booking patterns, we've identified peak demand periods, allowing hosts to adjust pricing and allocate resources effectively. Understanding the popularity of different accommodation types enables hosts to enhance their listings and cater to guest preferences more effectively. Additionally, insights into average length of stay facilitate better inventory management and turnover planning.
#
# Furthermore, correlations between guest demographics and booking behavior provide valuable insights for targeted marketing and personalized offerings. By investigating cancellation behavior and its correlations with historical data, hosts can develop strategies to minimize cancellations and foster customer loyalty. Moreover, analyzing customer preferences for booking channels informs marketing strategies, enhancing reach and engagement.
#
# In conclusion, leveraging data-driven insights from our analysis empowers Airbnb hosts and stakeholders to make informed decisions, optimize pricing strategies, enhance guest satisfaction, and drive business growth. With a deeper understanding of booking trends and guest preferences, hosts can navigate the competitive landscape more effectively, ultimately leading to long-term success and sustainability.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
